# %% [markdown]
# # Numerai EDA
# Exploration rapide des features et de la cible.

# %%
import pandas as pd
from pathlib import Path

train_path = Path('..') / 'data' / 'numerai_training_data.parquet'
if train_path.exists():
    df = pd.read_parquet(train_path)
    display(df.head())
    display(df.describe())
else:
    print('Training data not found, please download via workflow or manual step.')
