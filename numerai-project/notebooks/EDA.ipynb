# %% [markdown]
# # Numerai EDA
# Exploration rapide des features et de la cible.

# %%
import pandas as pd
from pathlib import Path

train_path = Path('..') / 'data' / 'numerai_training_data.parquet'
if train_path.exists():
    df = pd.read_parquet(train_path)
    display(df.head())
    display(df.describe())
else:
    print('Training data not found, please download via workflow or manual step.')
# Out:
#                    era data_type  feature_shaded_hallucinatory_dactylology  \
# id
# n0007b5abb0c3a25  0001     train                                         3
# n003bba8a98662e4  0001     train                                         4
# n003bee128c2fcfc  0001     train                                         2
# n0048ac83aff7194  0001     train                                         2
# n0055a2401ba6480  0001     train                                         4
#
#                   feature_itinerant_hexahedral_photoengraver  \
# id
# n0007b5abb0c3a25                                           4
# n003bba8a98662e4                                           2
# n003bee128c2fcfc                                           4
# n0048ac83aff7194                                           1
# n0055a2401ba6480                                           1
#
#                   feature_prudent_pileate_oven  \
# id
# n0007b5abb0c3a25                             0
# n003bba8a98662e4                             4
# n003bee128c2fcfc                             0
# n0048ac83aff7194                             3
# n0055a2401ba6480                             4
#
#                   feature_subalpine_apothegmatical_ajax  \
# id
# n0007b5abb0c3a25                                      3
# n003bba8a98662e4                                      4
# n003bee128c2fcfc                                      3
# n0048ac83aff7194                                      0
# n0055a2401ba6480                                      1
#
#                   feature_pistachio_atypical_malison  \
# id
# n0007b5abb0c3a25                                   3
# n003bba8a98662e4                                   0
# n003bee128c2fcfc                                   0
# n0048ac83aff7194                                   3
# n0055a2401ba6480                                   0
#
#                   feature_symmetrical_spongy_tricentenary  \
# id
# n0007b5abb0c3a25                                        1
# n003bba8a98662e4                                        0
# n003bee128c2fcfc                                        3
# n0048ac83aff7194                                        0
# n0055a2401ba6480                                        4
#
#                   feature_ungrounded_transpontine_winder  \
# id
# n0007b5abb0c3a25                                       1
# n003bba8a98662e4                                       4
# n003bee128c2fcfc                                       2
# n0048ac83aff7194                                       3
# n0055a2401ba6480                                       0
#
#                   feature_aseptic_eely_hemiplegia  ...  target_teager2b_20  \
# id                                                 ...
# n0007b5abb0c3a25                                0  ...                0.50
# n003bba8a98662e4                                4  ...                0.50
# n003bee128c2fcfc                                4  ...                1.00
# n0048ac83aff7194                                3  ...                0.25
# n0055a2401ba6480                                4  ...                0.50
#
#                   target_teager2b_60  target_tyler_20  target_tyler_60  \
# id
# n0007b5abb0c3a25                0.50             0.25             0.25
# n003bba8a98662e4                0.50             0.25             0.25
# n003bee128c2fcfc                1.00             1.00             0.75
# n0048ac83aff7194                0.25             0.25             0.25
# n0055a2401ba6480                0.50             0.25             0.50
#
#                   target_victor_20  target_victor_60  target_waldo_20  \
# id
# n0007b5abb0c3a25              0.25              0.25             0.25
# n003bba8a98662e4              0.25              0.00             0.25
# n003bee128c2fcfc              0.75              0.75             0.75
# n0048ac83aff7194              0.50              0.25             0.25
# n0055a2401ba6480              0.25              0.50             0.25
#
#                   target_waldo_60  target_xerxes_20  target_xerxes_60
# id
# n0007b5abb0c3a25             0.00              0.25              0.00
# n003bba8a98662e4             0.25              0.25              0.25
# n003bee128c2fcfc             1.00              0.75              0.75
# n0048ac83aff7194             0.25              0.25              0.25
# n0055a2401ba6480             0.50              0.25              0.50
#
# [5 rows x 2601 columns]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6     df = pd.read_parquet(train_path)
#       7     display(df.head())
# ----> 8     display(df.describe())
#       9 else:
#      10     print('Training data not found, please download via workflow or manual step.')
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\generic.py:12041, in NDFrame.describe(self, percentiles, include, exclude)
#   11799 @final
#   11800 def describe(
#   11801     self,
#    (...)  11804     exclude=None,
#   11805 ) -> Self:
#   11806     """
#   11807     Generate descriptive statistics.
#   11808
#    (...)  12039     max            NaN      3.0
#   12040     """
# > 12041     return describe_ndframe(
#   12042         obj=self,
#   12043         include=include,
#   12044         exclude=exclude,
#   12045         percentiles=percentiles,
#   12046     ).__finalize__(self, method="describe")
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\methods\describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
#      90 else:
#      91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
# ---> 97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\methods\describe.py:172, in DataFrameDescriber.describe(self, percentiles)
#     170 for _, series in data.items():
#     171     describe_func = select_describe_func(series)
# --> 172     ldesc.append(describe_func(series, percentiles))
#     174 col_names = reorder_columns(ldesc)
#     175 d = concat(
#     176     [x.reindex(col_names, copy=False) for x in ldesc],
#     177     axis=1,
#     178     sort=False,
#     179 )
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\methods\describe.py:233, in describe_numeric_1d(series, percentiles)
#     229 formatted_percentiles = format_percentiles(percentiles)
#     231 stat_index = ["count", "mean", "std", "min"] + formatted_percentiles + ["max"]
#     232 d = (
# --> 233     [series.count(), series.mean(), series.std(), series.min()]
#     234     + series.quantile(percentiles).tolist()
#     235     + [series.max()]
#     236 )
#     237 # GH#48340 - always return float on non-complex numeric data
#     238 dtype: DtypeObj | None
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\series.py:6613, in Series.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#    6604 @doc(make_doc("std", ndim=1))
#    6605 def std(
#    6606     self,
#    (...)   6611     **kwargs,
#    6612 ):
# -> 6613     return NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\generic.py:12423, in NDFrame.std(self, axis, skipna, ddof, numeric_only, **kwargs)
#   12415 def std(
#   12416     self,
#   12417     axis: Axis | None = 0,
#    (...)  12421     **kwargs,
#   12422 ) -> Series | float:
# > 12423     return self._stat_function_ddof(
#   12424         "std", nanops.nanstd, axis, skipna, ddof, numeric_only, **kwargs
#   12425     )
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\generic.py:12387, in NDFrame._stat_function_ddof(self, name, func, axis, skipna, ddof, numeric_only, **kwargs)
#   12384 elif axis is lib.no_default:
#   12385     axis = 0
# > 12387 return self._reduce(
#   12388     func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   12389 )
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\nanops.py:950, in nanstd(values, axis, skipna, ddof, mask)
#     947 orig_dtype = values.dtype
#     948 values, mask = _get_values(values, skipna, mask=mask)
# --> 950 result = np.sqrt(nanvar(values, axis=axis, skipna=skipna, ddof=ddof, mask=mask))
#     951 return _wrap_results(result, orig_dtype)
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File d:\Programmes\Miniconda3\envs\lgbm-gpu\Lib\site-packages\pandas\core\nanops.py:994, in nanvar(values, axis, skipna, ddof, mask)
#     992 mask = _maybe_get_mask(values, skipna, mask)
#     993 if dtype.kind in "iu":
# --> 994     values = values.astype("f8")
#     995     if mask is not None:
#     996         values[mask] = np.nan
#
# MemoryError: Unable to allocate 21.0 MiB for an array with shape (2746270,) and data type float64
