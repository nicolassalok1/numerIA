# %% [markdown]
# # Pipeline Numerai
#
# Prototype de feature engineering, entrainement, et evaluation.

# %%
from pathlib import Path
import pandas as pd

train_path = Path('..') / 'data' / 'numerai_training_data.parquet'
tournament_path = Path('..') / 'data' / 'numerai_tournament_data.parquet'

if train_path.exists():
    train_df = pd.read_parquet(train_path)
    display(train_df.head())
else:
    print('Training data missing, download via workflow or manual step.')

if tournament_path.exists():
    tour_df = pd.read_parquet(tournament_path)
    display(tour_df.head())
else:
    print('Tournament data missing, download via workflow or manual step.')
# Out:
#                    era data_type  feature_shaded_hallucinatory_dactylology  \
# id
# n0007b5abb0c3a25  0001     train                                         3
# n003bba8a98662e4  0001     train                                         4
# n003bee128c2fcfc  0001     train                                         2
# n0048ac83aff7194  0001     train                                         2
# n0055a2401ba6480  0001     train                                         4
#
#                   feature_itinerant_hexahedral_photoengraver  \
# id
# n0007b5abb0c3a25                                           4
# n003bba8a98662e4                                           2
# n003bee128c2fcfc                                           4
# n0048ac83aff7194                                           1
# n0055a2401ba6480                                           1
#
#                   feature_prudent_pileate_oven  \
# id
# n0007b5abb0c3a25                             0
# ...
