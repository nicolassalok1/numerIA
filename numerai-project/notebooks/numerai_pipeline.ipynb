# %% [markdown]
# # Numerai Pipeline Notebook
# Use this notebook to prototype feature engineering, model training, and evaluation.

# %%
import pandas as pd
import numpy as np

# TODO: load data and explore
print('Notebook skeleton ready')
